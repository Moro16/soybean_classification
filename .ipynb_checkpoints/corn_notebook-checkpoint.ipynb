# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shutil

# %%
dataset_path = "raw_data/Corn seeds/raw"
train_path = "raw_data/Corn seeds/train"
val_path = "raw_data/Corn seeds/val"
test_path = "raw_data/Corn seeds/test"

# %%
os.makedirs(train_path, exist_ok=True)
os.makedirs(val_path, exist_ok=True)
os.makedirs(test_path, exist_ok=True)

# %%
train_dir = "raw_data/Corn seeds/train"
val_dir = "raw_data/Corn seeds/test"
test_dir = "raw_data/Corn seeds/test"

# %%
train_df = pd.DataFrame(columns=["path", "class"])
val_df = pd.DataFrame(columns=["path", "class"])
test_df = pd.DataFrame(columns=["path", "class"])

# %%
# img = load_img(f'{train_path}/broken/3.jpg')
# x = img_to_array(img)/255
# img

# %%
# x.shape

# %%
# train_ratio = 0.7
# val_ratio = .15

# for class_folder in os.listdir(dataset_path):
#     class_path = os.path.join(dataset_path, class_folder)
#     images = os.listdir(class_path)
#     random.shuffle(images)

#     # Calculate the split index
#     split_index = int(train_ratio * len(images))
#     val_len = int(len(images) * (1-val_ratio))

#     # Split the images into training and testing sets
#     train_images = images[:split_index]
#     val_images = images[split_index:val_len]
#     test_images = images[val_len:]

#     # Create class folders in the training and testing directories
#     train_class_path = os.path.join(train_path, class_folder)
#     val_class_path = os.path.join(val_path, class_folder)
#     test_class_path = os.path.join(test_path, class_folder)
#     os.makedirs(train_class_path, exist_ok=True)
#     os.makedirs(val_class_path, exist_ok=True)
#     os.makedirs(test_class_path, exist_ok=True)

#     # Move images to the respective class folders in training and testing
#     for image in train_images:
#         src = os.path.join(class_path, image)
#         dest = os.path.join(train_class_path, image)
#         shutil.copy(src, dest)

#     for image in val_images:
#         src = os.path.join(class_path, image)
#         dest = os.path.join(val_class_path, image)
#         shutil.copy(src, dest)

#     for image in test_images:
#         src = os.path.join(class_path, image)
#         dest = os.path.join(test_class_path, image)
#         shutil.copy(src, dest)

# %%
def plot_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(15,5))
    ax[0].set_title('loss')
    ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax[1].set_title('accuracy')
    ax[1].plot(history.epoch, history.history["accuracy"], label="Train acc")
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation acc")
    ax[0].legend()
    ax[1].legend()

# %%
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img

from tensorflow.keras.models import Sequential, Model, load_model, save_model
from tensorflow.keras import layers, optimizers, callbacks
from tensorflow.keras.utils import image_dataset_from_directory

from tensorflow.keras.layers import Dense,Flatten,Conv2D,Activation,Dropout,MaxPool2D,Rescaling,RandomFlip
# Out:
# 2024-11-30 11:23:28.226328: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-30 11:23:28.226370: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-30 11:23:28.227353: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-30 11:23:28.233842: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-30 11:23:28.923256: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-11-30 11:23:29.600569: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-30 11:23:29.619346: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-30 11:23:29.619396: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %% [markdown]
# # tentativa

# %%
model = Sequential()

model.add(layers.Rescaling(1/255, input_shape=(192,192,3)))

model.add(layers.RandomFlip(mode='horizontal'))
model.add(layers.RandomFlip(mode='vertical'))
model.add(layers.RandomZoom(-.3,-.3))
model.add(layers.RandomContrast(.25))

model.add(layers.Conv2D(filters=32, kernel_size=(5,5), activation='relu', padding='valid'))
model.add(layers.MaxPool2D(pool_size=(4,4), padding='same'))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(filters=64, kernel_size=(4,4), activation='relu', padding='valid'))
model.add(layers.MaxPool2D(pool_size=(4,4), padding='same'))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='valid'))
model.add(layers.MaxPool2D(pool_size=(2,2), padding='same'))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='valid'))
model.add(layers.MaxPool2D(pool_size=(2,2), padding='same'))
model.add(layers.BatchNormalization())

model.add(layers.Flatten())

model.add(layers.Dense(128, activation='relu'))

model.add(layers.Dense(64, activation='relu'))

model.add(layers.Dense(4,activation="softmax"))
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_11 (Rescaling)    (None, 192, 192, 3)       0
#
#  random_flip_22 (RandomFlip  (None, 192, 192, 3)       0
#  )
#
#  random_flip_23 (RandomFlip  (None, 192, 192, 3)       0
#  )
#
#  random_zoom_3 (RandomZoom)  (None, 192, 192, 3)       0
#
#  random_contrast_8 (RandomC  (None, 192, 192, 3)       0
#  ontrast)
#
#  conv2d_46 (Conv2D)          (None, 192, 192, 32)      2432
#
#  max_pooling2d_44 (MaxPooli  (None, 48, 48, 32)        0
#  ng2D)
#
#  batch_normalization_40 (Ba  (None, 48, 48, 32)        128
#  tchNormalization)
#
#  conv2d_47 (Conv2D)          (None, 48, 48, 64)        32832
#
#  max_pooling2d_45 (MaxPooli  (None, 12, 12, 64)        0
#  ng2D)
#
#  batch_normalization_41 (Ba  (None, 12, 12, 64)        256
#  tchNormalization)
#
#  conv2d_48 (Conv2D)          (None, 12, 12, 128)       73856
#
#  max_pooling2d_46 (MaxPooli  (None, 6, 6, 128)         0
#  ng2D)
#
#  batch_normalization_42 (Ba  (None, 6, 6, 128)         512
#  tchNormalization)
#
#  conv2d_49 (Conv2D)          (None, 6, 6, 256)         295168
#
#  max_pooling2d_47 (MaxPooli  (None, 3, 3, 256)         0
#  ng2D)
#
#  batch_normalization_43 (Ba  (None, 3, 3, 256)         1024
#  tchNormalization)
#
#  flatten_10 (Flatten)        (None, 2304)              0
#
#  dense_30 (Dense)            (None, 128)               295040
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_31 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_32 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 709764 (2.71 MB)
# Trainable params: 708804 (2.70 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %% [markdown]
# # Model 69,84%

# %%
# model = Sequential()

# model.add(layers.Rescaling(1/255, input_shape=(192,192,3)))

# model.add(layers.RandomFlip(mode='horizontal'))
# model.add(layers.RandomFlip(mode='vertical'))
# model.add(layers.RandomZoom(-.3,-.3))
# model.add(layers.RandomContrast(.25))

# model.add(layers.Conv2D(filters=32, kernel_size=(5,5), activation='relu', padding='same'))
# model.add(layers.MaxPool2D(pool_size=(4,4), padding='same'))
# model.add(layers.BatchNormalization())

# model.add(layers.Conv2D(filters=64, kernel_size=(4,4), activation='relu', padding='same'))
# model.add(layers.MaxPool2D(pool_size=(4,4), padding='same'))
# model.add(layers.BatchNormalization())

# model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(layers.MaxPool2D(pool_size=(2,2), padding='same'))
# model.add(layers.BatchNormalization())

# model.add(layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(layers.MaxPool2D(pool_size=(2,2), padding='same'))
# model.add(layers.BatchNormalization())

# model.add(layers.Flatten())

# model.add(layers.Dense(128, activation='relu'))

# model.add(layers.Dense(64, activation='relu'))

# model.add(layers.Dense(4,activation="softmax"))
# model.summary()

# %%
# opt = optimizers.SGD(learning_rate=.001, momentum=0.9)
# model.compile(loss="categorical_crossentropy",
#               optimizer=opt,
#               metrics=["accuracy"])

# %%
adam = optimizers.Adam(learning_rate = .1)
model.compile(loss='categorical_crossentropy',
             optimizer=adam,
             metrics=['accuracy'])

# %%
batch_size = 64
train_ds = image_dataset_from_directory(
    train_dir,
    labels = 'inferred',
    label_mode = 'categorical',
    class_names = ['broken', 'discolored', 'pure', 'silkcut'],
    image_size=(192,192),
    batch_size=batch_size
)

val_ds = image_dataset_from_directory(
    val_dir,
    labels="inferred",
    label_mode = 'categorical',
    class_names = ['broken', 'discolored', 'pure', 'silkcut'],
    image_size=(192,192),
    batch_size=batch_size
)

test_ds = image_dataset_from_directory(
    test_dir,
    labels="inferred",
    label_mode = 'categorical',
    class_names = ['broken', 'discolored', 'pure', 'silkcut'],
    image_size=(192,192),
    batch_size=batch_size
)
# Out:
# Found 4882 files belonging to 4 classes.
# Found 1048 files belonging to 4 classes.
# Found 1048 files belonging to 4 classes.

# %%
MODEL = "model_1.keras"

modelCheckpoint = callbacks.ModelCheckpoint(MODEL,
                                            monitor="val_accuracy",
                                            verbose=0,
                                            save_best_only=True)

LRreducer = callbacks.ReduceLROnPlateau(monitor="val_accuracy",
                                        factor=0.1,
                                        patience=10,
                                        verbose=1,
                                        min_lr=0)

EarlyStopper = callbacks.EarlyStopping(monitor='val_accuracy',
                                       patience=30,
                                       verbose=0,
                                       restore_best_weights=True)

# %%
# %%time
history = model.fit(
        train_ds,
        epochs=900,
        validation_data=val_ds,
        callbacks=[modelCheckpoint, LRreducer, EarlyStopper]
        )
# Out:
# Epoch 1/900
# 77/77 [==============================] - 7s 57ms/step - loss: 1.6680 - accuracy: 0.3474 - val_loss: 9.4371 - val_accuracy: 0.2510 - lr: 0.0100
# Epoch 2/900
# 77/77 [==============================] - 5s 60ms/step - loss: 1.2405 - accuracy: 0.3966 - val_loss: 1.3722 - val_accuracy: 0.3034 - lr: 0.0100
# Epoch 3/900
# 77/77 [==============================] - 4s 56ms/step - loss: 1.2248 - accuracy: 0.4117 - val_loss: 1.4961 - val_accuracy: 0.3177 - lr: 0.0100
# Epoch 4/900
# 77/77 [==============================] - 5s 59ms/step - loss: 1.2283 - accuracy: 0.4041 - val_loss: 1.1958 - val_accuracy: 0.4542 - lr: 0.0100
# Epoch 5/900
# 77/77 [==============================] - 6s 78ms/step - loss: 1.2088 - accuracy: 0.4332 - val_loss: 1.2935 - val_accuracy: 0.4103 - lr: 0.0100
# Epoch 6/900
900
# 77/77 [==============================] - 4s 57ms/step - loss: 0.5973 - accuracy: 0.7534 - val_loss: 0.9097 - val_accuracy: 0.6594 - lr: 1.0000e-05
# Epoch 139/900
# 77/77 [==============================] - 5s 57ms/step - loss: 0.5921 - accuracy: 0.7528 - val_loss: 0.9088 - val_accuracy: 0.6603 - lr: 1.0000e-05
# Epoch 140/900
# 76/77 [============================>.] - ETA: 0s - loss: 0.6044 - accuracy: 0.7477
# Epoch 140: ReduceLROnPlateau reducing learning rate to 9.99999883788405e-07.
# 77/77 [==============================] - 5s 61ms/step - loss: 0.6048 - accuracy: 0.7474 - val_loss: 0.9083 - val_accuracy: 0.6603 - lr: 1.0000e-05
# Epoch 141/900
# 77/77 [==============================] - 6s 79ms/step - loss: 0.5998 - accuracy: 0.7540 - val_loss: 0.9102 - val_accuracy: 0.6603 - lr: 1.0000e-06
# Epoch 142/900
# 77/77 [==============================] - 5s 59ms/step - loss: 0.5927 - accuracy: 0.7610 - val_loss: 0.9096 - val_accuracy: 0.6603 - lr: 1.0000e-06
# Epoch 143/900
# 77/77 [==============================] - 4s 55ms/step - loss: 0.5963 - accuracy: 0.7526 - val_loss: 0.9090 - val_accuracy: 0.6613 - lr: 1.0000e-06
# Epoch 144/900
# 77/77 [==============================] - 4s 57ms/step - loss: 0.5898 - accuracy: 0.7612 - val_loss: 0.9093 - val_accuracy: 0.6603 - lr: 1.0000e-06
# Epoch 145/900
# 77/77 [==============================] - 4s 56ms/step - loss: 0.6025 - accuracy: 0.7519 - val_loss: 0.9098 - val_accuracy: 0.6613 - lr: 1.0000e-06
# Epoch 146/900
# 77/77 [==============================] - 5s 61ms/step - loss: 0.5991 - accuracy: 0.7528 - val_loss: 0.9097 - val_accuracy: 0.6613 - lr: 1.0000e-06
# Epoch 147/900
# 77/77 [==============================] - 5s 59ms/step - loss: 0.5923 - accuracy: 0.7565 - val_loss: 0.9090 - val_accuracy: 0.6603 - lr: 1.0000e-06
# Epoch 148/900
# 77/77 [==============================] - 7s 85ms/step - loss: 0.5940 - accuracy: 0.7554 - val_loss: 0.9091 - val_accuracy: 0.6632 - lr: 1.0000e-06
# Epoch 149/900
# 77/77 [==============================] - 5s 59ms/step - loss: 0.6013 - accuracy: 0.7454 - val_loss: 0.9094 - val_accuracy: 0.6594 - lr: 1.0000e-06
# Epoch 150/900
# 77/77 [==============================] - ETA: 0s - loss: 0.5997 - accuracy: 0.7534
# Epoch 150: ReduceLROnPlateau reducing learning rate to 9.99999883788405e-08.
# 77/77 [==============================] - 4s 56ms/step - loss: 0.5997 - accuracy: 0.7534 - val_loss: 0.9095 - val_accuracy: 0.6603 - lr: 1.0000e-06
# CPU times: user 25min 52s, sys: 3min 1s, total: 28min 54s
# Wall time: 11min 50s

# %%
plot_history(history)

# %%
model.evaluate(test_ds)
# Out:
# 17/17 [==============================] - 0s 20ms/step - loss: 0.9027 - accuracy: 0.6670
# [0.9027225971221924, 0.6669847369194031]

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 192, 192, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>

# %%
# model.save("model_corn_val_loss:0.0.8671-val_accuracy:0.6985")
